# %% [markdown]
# ### Import libraries as needed

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchsummary import summary
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset, SubsetRandomSampler, Dataset
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import time
import copy

# %% [markdown]
# ### Define helper functions

# %%
###########################################################################################

# Function to plot the training and validation accuracy and loss --------------------------
def plot_history(history):
    fig, axs = plt.subplots(2)

    # Create accuracy subplot
    axs[0].plot([acc.cpu().numpy() for acc in history['train_acc']], label="train accuracy")
    axs[0].plot([acc.cpu().numpy() for acc in history['val_acc']], label="validation accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy Evaluation")

    # Create error subplot
    axs[1].plot(history['train_loss'], label="train error")
    axs[1].plot(history['val_loss'], label="validation error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error Evaluation")

    plt.show()

###########################################################################################

# Function to visualize some images before you train --------------------------------------
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    plt.imshow(inp, cmap='gray')
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

############################################################################################

# Function to visualize sample count before split ------------------------------------------
def plot_class_distribution(counts, title):
    labels = [f"{idx}: {idx_to_class[idx]}" for idx in counts.keys()]
    values = list(counts.values())

    plt.figure(figsize=(10,5))
    plt.bar(labels, values)
    plt.xlabel('Class')
    plt.ylabel('Count')
    plt.title(title)
    plt.xticks(rotation=90)
    plt.show()

############################################################################################

# Function to plot the confusion matrix
def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 10))
    sns.heatmap(cm, annot=True, fmt=".0f", linewidths=.5, square=True, cmap='Blues');
    plt.ylabel('Actual Label');
    plt.xlabel('Predicted Label');
    plt.title('Confusion Matrix', size=15);
    plt.show()

############################################################################################

# Function for classification report for perfomance metrics
from sklearn import preprocessing
def calculate_metrics(y_true, y_pred):
    le = preprocessing.LabelEncoder()
    le.fit(y_true)
    class_names = [str(cls) for cls in le.classes_]
    print(classification_report(y_true, y_pred, target_names=class_names))

############################################################################################

# %% [markdown]
# ### Define function to **train** the model

# %%
def train_model(model, criterion, optimizer, scheduler, dataloaders, num_epochs=80):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model.to(device)

    # Initialize the history
    history = {'train_loss': [], 'val_loss': [], 'train_acc': [], 'val_acc': []}

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['Train', 'Validation']:
            if phase == 'Train':
                model.train()  # Set model to training mode
                print("training phase")
            else:
                model.eval()   # Set model to evaluate mode
                print("eval phase")

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:

                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'Train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'Train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                #print("end inner loop")

            if phase == 'Train':
                scheduler.step()

            # epoch_loss = running_loss / dataset_sizes[phase]
            # epoch_acc = running_corrects.double() / dataset_sizes[phase]
            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'Validation' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
                torch.save(model.state_dict(), f'bestmodel_complexCNN_80epoch.pth')

            # Save the loss and accuracy in history
            if phase == 'Train':
                history['train_loss'].append(epoch_loss)
                history['train_acc'].append(epoch_acc)
            else:
                history['val_loss'].append(epoch_loss)
                history['val_acc'].append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, history

# %% [markdown]
# ### Load data, setup dataloaders, and visualize sample counts

# %%
# Define your transformations
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),  # Horizontal mirroring
    transforms.RandomRotation(7),  # ±10 degree rotations
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),  # Convert the PIL Image to a tensor
])

# Define your transformations for the validation and test sets
val_test_transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),  # Convert the PIL Image to a tensor
])

train_dir = 'C:/Users/Anish Patel/Desktop/ENSF645 Final Project/Dataset/train'
test_dir = 'C:/Users/Anish Patel/Desktop/ENSF645 Final Project/Dataset/test'

# Load the datasets
train_data = datasets.ImageFolder(train_dir, transform=train_transform)
test_data = datasets.ImageFolder(test_dir, transform=val_test_transform)

# %%
print(train_data.classes)
# Out:
# ['angry', 'fear', 'happy', 'sad', 'surprise']

# %%
# Get the class names
class_names_train = test_data.classes
class_names_test = test_data.classes

# Create a dictionary mapping indices to class names
idx_to_class_train = {i: class_name for i, class_name in enumerate(class_names_train)}
idx_to_class_test = {i: class_name for i, class_name in enumerate(class_names_test)}

# Count labels in the original dataset for train and test
train_counts = Counter(train_data.targets)
test_counts = Counter(test_data.targets)

# Adjust the counts to exclude 'happy_2'
train_counts = {i: count for i, count in train_counts.items() if i in idx_to_class_train.keys()}

# Print the counts
print("Train Counts:", {idx_to_class_train[i]: count for i, count in train_counts.items()})
print("Test Counts:", {idx_to_class_test[i]: count for i, count in test_counts.items()})
# Out:
# Train Counts: {'angry': 3995, 'fear': 4097, 'happy': 7215, 'sad': 4830, 'surprise': 3171}
# Test Counts: {'angry': 958, 'fear': 1024, 'happy': 1774, 'sad': 1247, 'surprise': 831}

# %%
# Get the indices of the samples in the validation and test sets
test_indices = [i for i, (img_path, _) in enumerate(test_data.imgs) if 'Private' in img_path]
valid_indices = [i for i, (img_path, _) in enumerate(test_data.imgs) if 'Private' not in img_path]

# Create subset datasets
validation_data = torch.utils.data.Subset(test_data, valid_indices)
test_data = torch.utils.data.Subset(test_data, test_indices)

# Create data loaders
batch_size = 32
num_workers = 2
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=num_workers)
validation_loader = DataLoader(validation_data, batch_size=batch_size, shuffle=True, num_workers=num_workers)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=True, num_workers=num_workers)

dataloaders = {
    'Train': train_loader,
    'Validation': validation_loader,
    'Test': test_loader
}

# %%
print("Length of Train Loader: ", len(dataloaders['Train']))
print("Length of Validation Loader: ", len(dataloaders['Validation']))
print("Total count of samples in train set:", len(train_data))
print("Total count of samples in validation set:", len(validation_data))
print("Total count of samples in test set:", len(test_data))
# Out:
# Length of Train Loader:  729
# Length of Validation Loader:  92
# Total count of samples in train set: 23308
# Total count of samples in validation set: 2926
# Total count of samples in test set: 2908

# %%
# Get the class names
class_names = train_data.classes

# Create a dictionary mapping indices to class names
idx_to_class = {i: class_name for i, class_name in enumerate(class_names)}

# Count labels in the original dataset for train
original_counts = Counter(train_data.targets)

# Count labels in the subsets
valid_counts = Counter(test_data.dataset.targets[i] for i in valid_indices)
test_counts = Counter(test_data.dataset.targets[i] for i in test_indices)

# Plot
plot_class_distribution(original_counts, 'Train Counts')
plot_class_distribution(valid_counts, 'Validation Counts')
plot_class_distribution(test_counts, 'Test Counts')

# %%
print("Train Counts:", {idx_to_class[i]: count for i, count in original_counts.items()})
print("Validation Counts:", {idx_to_class[i]: count for i, count in valid_counts.items()})
print("Test Counts:", {idx_to_class[i]: count for i, count in test_counts.items()})
# Out:
# Train Counts: {'angry': 3995, 'fear': 4097, 'happy': 7215, 'sad': 4830, 'surprise': 3171}
# Validation Counts: {'angry': 467, 'fear': 496, 'happy': 895, 'sad': 653, 'surprise': 415}
# Test Counts: {'angry': 491, 'fear': 528, 'happy': 879, 'sad': 594, 'surprise': 416}

# %% [markdown]
# ####Data seems to be imbalanced with happy class having a lot more data, remaining classes seem to be somewhat equal

# %% [markdown]
# ### Visualize some sample from the training set before training

# %%
# Get a batch of training data
inputs, classes = next(iter(train_loader))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)
imshow(out)

# %% [markdown]
# ### Define a baseline CNN model

# %%
import torch.nn.functional as F

import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 128, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(128)
        self.pool1 = nn.MaxPool2d(2, 2)
        self.dropout1 = nn.Dropout(0.25)

        self.conv2 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(256)
        self.pool2 = nn.MaxPool2d(2, 2)
        self.dropout2 = nn.Dropout(0.25)

        self.conv3 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(512)
        self.pool3 = nn.MaxPool2d(2, 2)
        self.dropout3 = nn.Dropout(0.25)

        self.conv4 = nn.Conv2d(512, 1024, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(1024)
        self.pool4 = nn.MaxPool2d(2, 2)
        self.dropout4 = nn.Dropout(0.25)

        self.conv5 = nn.Conv2d(1024, 1024, kernel_size=3, padding=1)
        self.bn5 = nn.BatchNorm2d(1024)
        self.pool5 = nn.MaxPool2d(2, 2)
        self.dropout5 = nn.Dropout(0.25)

        self.fc1 = nn.Linear(1024, 512)
        self.bn6 = nn.BatchNorm1d(512)
        self.dropout6 = nn.Dropout(0.5)

        self.fc2 = nn.Linear(512, 256)
        self.bn7 = nn.BatchNorm1d(256)
        self.dropout7 = nn.Dropout(0.5)

        self.fc3 = nn.Linear(256, 5)

    def forward(self, x):
        x = self.pool1(F.relu(self.bn1(self.conv1(x))))
        x = self.dropout1(x)

        x = self.pool2(F.relu(self.bn2(self.conv2(x))))
        x = self.dropout2(x)

        x = self.pool3(F.relu(self.bn3(self.conv3(x))))
        x = self.dropout3(x)

        x = self.pool4(F.relu(self.bn4(self.conv4(x))))
        x = self.dropout4(x)

        x = self.pool5(F.relu(self.bn5(self.conv5(x))))
        x = self.dropout5(x)

        x = x.view(x.size(0), -1)  # Flatten layer

        x = F.relu(self.bn6(self.fc1(x)))
        x = self.dropout6(x)

        x = F.relu(self.bn7(self.fc2(x)))
        x = self.dropout7(x)

        x = self.fc3(x)
        return F.log_softmax(x, dim=1)

# %%
# Assuming that your model is defined and moved to the correct device
model = Net()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
  print("using gpu")
else:
  print("using cpu")

model = model.to(device)

# Print the summary
summary(model, input_size=(1, 48, 48))
# Out:
# using gpu
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 128, 48, 48]           1,280
#        BatchNorm2d-2          [-1, 128, 48, 48]             256
#          MaxPool2d-3          [-1, 128, 24, 24]               0
#            Dropout-4          [-1, 128, 24, 24]               0
#             Conv2d-5          [-1, 256, 24, 24]         295,168
#        BatchNorm2d-6          [-1, 256, 24, 24]             512
#          MaxPool2d-7          [-1, 256, 12, 12]               0
#            Dropout-8          [-1, 256, 12, 12]               0
#             Conv2d-9          [-1, 512, 12, 12]       1,180,160
#       BatchNorm2d-10          [-1, 512, 12, 12]           1,024
#         MaxPool2d-11            [-1, 512, 6, 6]               0
#           Dropout-12            [-1, 512, 6, 6]               0
#            Conv2d-13           [-1, 1024, 6, 6]       4,719,616
#       BatchNorm2d-14           [-1, 1024, 6, 6]           2,048
#         MaxPool2d-15           [-1, 1024, 3, 3]               0
#           Dropout-16           [-1, 1024, 3, 3]               0
#            Conv2d-17           [-1, 1024, 3, 3]       9,438,208
#       BatchNorm2d-18           [-1, 1024, 3, 3]           2,048
#         MaxPool2d-19           [-1, 1024, 1, 1]               0
#           Dropout-20           [-1, 1024, 1, 1]               0
#            Linear-21                  [-1, 512]         524,800
#       BatchNorm1d-22                  [-1, 512]           1,024
#           Dropout-23                  [-1, 512]               0
#            Linear-24                  [-1, 256]         131,328
#       BatchNorm1d-25                  [-1, 256]             512
#           Dropout-26                  [-1, 256]               0
#            Linear-27                    [-1, 5]           1,285
# ================================================================
# Total params: 16,299,269
# Trainable params: 16,299,269
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 10.72
# Params size (MB): 62.18
# Estimated Total Size (MB): 72.91
# ----------------------------------------------------------------

# %% [markdown]
# ### Send model to gpu and define loss function, step optimizer, learning rate scheduler

# %%
# Define the criterion
criterion = nn.CrossEntropyLoss()

# Define the optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Define the learning rate scheduler
scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

# Calculate dataset sizes
dataset_sizes = {
    'Train': len(train_data),
    'Validation': len(validation_data),
    'Test': len(test_data)
}

# %% [markdown]
# ### Train the model

# %%
model, history = train_model(model, criterion, optimizer, scheduler, dataloaders, num_epochs=80)
# model = train_model(model, criterion, optimizer, dataloaders, num_epochs=80)
# Out:
# Epoch 0/79
# ----------
# training phase
# Train Loss: 1.3947 Acc: 0.4089
# eval phase
# Validation Loss: 1.1848 Acc: 0.5236
#
# Epoch 1/79
# ----------
# training phase
# Train Loss: 1.1334 Acc: 0.5339
# eval phase
# Validation Loss: 1.0433 Acc: 0.5807
#
# Epoch 2/79
# ----------
# training phase
# Train Loss: 1.0512 Acc: 0.5765
# eval phase
# Validation Loss: 0.9309 Acc: 0.6316
#
# Epoch 3/79
# ----------
# training phase
# Train Loss: 1.0056 Acc: 0.5978
# eval phase
# Validation Loss: 0.9326 Acc: 0.6213
#
# Epoch 4/79
# ----------
# training phase
# Train Loss: 0.9728 Acc: 0.6106
# eval phase
# Validation Loss: 0.9024 Acc: 0.6384
#
# Epoch 5/79
# ----------
# training phase
# Train Loss: 0.9485 Acc: 0.6272
# eval phase
# Validation Loss: 0.8669 Acc: 0.6514
#
# Epoch 6/79
# ----------
# training phase
# Train Loss: 0.9181 Acc: 0.6385
# eval phase
# Validation Loss: 0.9151 Acc: 0.6343
#
# Epoch 7/79
# ----------
# training phase
# Train Loss: 0.8443 Acc: 0.6680
# eval phase
# Validation Loss: 0.8186 Acc: 0.6757
#
# Epoch 8/79
# ----------
# training phase
# Train Loss: 0.8167 Acc: 0.6783
# eval phase
# Validation Loss: 0.8085 Acc: 0.6897
#
# Epoch 9/79
# ----------
# training phase
# Train Loss: 0.8013 Acc: 0.6834
# eval phase
# Validation Loss: 0.7990 Acc: 0.6883
#
# Epoch 10/79
# ----------
# training phase
# Train Loss: 0.7829 Acc: 0.6941
# eval phase
# Validation Loss: 0.7986 Acc: 0.6890
#
# Epoch 11/79
# ----------
# training phase
# Train Loss: 0.7828 Acc: 0.6937
# eval phase
# Validation Loss: 0.7903 Acc: 0.6955
#
# Epoch 12/79
# ----------
# training phase
# Train Loss: 0.7614 Acc: 0.7003
# eval phase
# Validation Loss: 0.7900 Acc: 0.6972
#
# Epoch 13/79
# ----------
# training phase
# Train Loss: 0.7576 Acc: 0.7041
# eval phase
# Validation Loss: 0.7850 Acc: 0.6992
#
# Epoch 14/79
# ----------
# training phase
# Train Loss: 0.7434 Acc: 0.7098
# eval phase
# Validation Loss: 0.7803 Acc: 0.7013
#
# Epoch 15/79
# ----------
# training phase
# Train Loss: 0.7419 Acc: 0.7105
# eval phase
# Validation Loss: 0.7805 Acc: 0.7023
#
# Epoch 16/79
# ----------
# training phase
# Train Loss: 0.7401 Acc: 0.7119
# eval phase
# Validation Loss: 0.7792 Acc: 0.7006
#
# Epoch 17/79
# ----------
# training phase
# Train Loss: 0.7301 Acc: 0.7140
# eval phase
# Validation Loss: 0.7776 Acc: 0.7027
#
# Epoch 18/79
# ----------
# training phase
# Train Loss: 0.7320 Acc: 0.7140
# eval phase
# Validation Loss: 0.7833 Acc: 0.7054
#
# Epoch 19/79
# ----------
# training phase
# Train Loss: 0.7314 Acc: 0.7130
# eval phase
# Validation Loss: 0.7808 Acc: 0.7013
#
# Epoch 20/79
# ----------
# training phase
# Train Loss: 0.7322 Acc: 0.7117
# eval phase
# Validation Loss: 0.7800 Acc: 0.7051
#
# Epoch 21/79
# ----------
# training phase
# Train Loss: 0.7315 Acc: 0.7152
# eval phase
# Validation Loss: 0.7788 Acc: 0.7040
#
# Epoch 22/79
# ----------
# training phase
# Train Loss: 0.7278 Acc: 0.7146
# eval phase
# Validation Loss: 0.7784 Acc: 0.7023
#
# Epoch 23/79
# ----------
# training phase
# Train Loss: 0.7280 Acc: 0.7149
# eval phase
# Validation Loss: 0.7846 Acc: 0.7006
#
# Epoch 24/79
# ----------
# training phase
# Train Loss: 0.7248 Acc: 0.7152
# eval phase
# Validation Loss: 0.7838 Acc: 0.7044
#
# Epoch 25/79
# ----------
# training phase
# Train Loss: 0.7285 Acc: 0.7176
# eval phase
# Validation Loss: 0.7802 Acc: 0.7027
#
# Epoch 26/79
# ----------
# training phase
# Train Loss: 0.7291 Acc: 0.7170
# eval phase
# Validation Loss: 0.7767 Acc: 0.7033
#
# Epoch 27/79
# ----------
# training phase
# Train Loss: 0.7289 Acc: 0.7183
# eval phase
# Validation Loss: 0.7767 Acc: 0.7044
#
# Epoch 28/79
# ----------
# training phase
# Train Loss: 0.7239 Acc: 0.7180
# eval phase
# Validation Loss: 0.7782 Acc: 0.7020
#
# Epoch 29/79
# ----------
# training phase
# Train Loss: 0.7266 Acc: 0.7162
# eval phase
# Validation Loss: 0.7769 Acc: 0.7006
#
# Epoch 30/79
# ----------
# training phase
# Train Loss: 0.7288 Acc: 0.7177
# eval phase
# Validation Loss: 0.7773 Acc: 0.7068
#
# Epoch 31/79
# ----------
# training phase
# Train Loss: 0.7286 Acc: 0.7127
# eval phase
# Validation Loss: 0.7751 Acc: 0.7033
#
# Epoch 32/79
# ----------
# training phase
# Train Loss: 0.7279 Acc: 0.7129
# eval phase
# Validation Loss: 0.7734 Acc: 0.7040
#
# Epoch 33/79
# ----------
# training phase
# Train Loss: 0.7254 Acc: 0.7147
# eval phase
# Validation Loss: 0.7785 Acc: 0.7040
#
# Epoch 34/79
# ----------
# training phase
# Train Loss: 0.7283 Acc: 0.7180
# eval phase
# Validation Loss: 0.7771 Acc: 0.7064
#
# Epoch 35/79
# ----------
# training phase
# Train Loss: 0.7317 Acc: 0.7178
# eval phase
# Validation Loss: 0.7797 Acc: 0.7054
#
# Epoch 36/79
# ----------
# training phase
# Train Loss: 0.7247 Acc: 0.7180
# eval phase
# Validation Loss: 0.7830 Acc: 0.7051
#
# Epoch 37/79
# ----------
# training phase
# Train Loss: 0.7245 Acc: 0.7170
# eval phase
# Validation Loss: 0.7795 Acc: 0.7047
#
# Epoch 38/79
# ----------
# training phase
# Train Loss: 0.7317 Acc: 0.7131
# eval phase
# Validation Loss: 0.7815 Acc: 0.7057
#
# Epoch 39/79
# ----------
# training phase
# Train Loss: 0.7286 Acc: 0.7129
# eval phase
# Validation Loss: 0.7798 Acc: 0.7047
#
# Epoch 40/79
# ----------
# training phase
# Train Loss: 0.7307 Acc: 0.7100
# eval phase
# Validation Loss: 0.7793 Acc: 0.7057
#
# Epoch 41/79
# ----------
# training phase
# Train Loss: 0.7260 Acc: 0.7154
# eval phase
# Validation Loss: 0.7747 Acc: 0.7057
#
# Epoch 42/79
# ----------
# training phase
# Train Loss: 0.7259 Acc: 0.7167
# eval phase
# Validation Loss: 0.7830 Acc: 0.7044
#
# Epoch 43/79
# ----------
# training phase
# Train Loss: 0.7288 Acc: 0.7164
# eval phase
# Validation Loss: 0.7805 Acc: 0.7037
#
# Epoch 44/79
# ----------
# training phase
# Train Loss: 0.7208 Acc: 0.7179
# eval phase
# Validation Loss: 0.7812 Acc: 0.7040
#
# Epoch 45/79
# ----------
# training phase
# Train Loss: 0.7263 Acc: 0.7163
# eval phase
# Validation Loss: 0.7790 Acc: 0.7047
#
# Epoch 46/79
# ----------
# training phase
# Train Loss: 0.7221 Acc: 0.7180
# eval phase
# Validation Loss: 0.7789 Acc: 0.7030
#
# Epoch 47/79
# ----------
# training phase
# Train Loss: 0.7217 Acc: 0.7161
# eval phase
# Validation Loss: 0.7787 Acc: 0.7033
#
# Epoch 48/79
# ----------
# training phase
# Train Loss: 0.7313 Acc: 0.7136
# eval phase
# Validation Loss: 0.7815 Acc: 0.7040
#
# Epoch 49/79
# ----------
# training phase
# Train Loss: 0.7352 Acc: 0.7124
# eval phase
# Validation Loss: 0.7774 Acc: 0.7068
#
# Epoch 50/79
# ----------
# training phase
# Train Loss: 0.7246 Acc: 0.7180
# eval phase
# Validation Loss: 0.7757 Acc: 0.7047
#
# Epoch 51/79
# ----------
# training phase
# Train Loss: 0.7247 Acc: 0.7177
# eval phase
# Validation Loss: 0.7749 Acc: 0.7068
#
# Epoch 52/79
# ----------
# training phase
# Train Loss: 0.7319 Acc: 0.7140
# eval phase
# Validation Loss: 0.7752 Acc: 0.7054
#
# Epoch 53/79
# ----------
# training phase
# Train Loss: 0.7248 Acc: 0.7171
# eval phase
# Validation Loss: 0.7776 Acc: 0.7047
#
# Epoch 54/79
# ----------
# training phase
# Train Loss: 0.7261 Acc: 0.7177
# eval phase
# Validation Loss: 0.7768 Acc: 0.7033
#
# Epoch 55/79
# ----------
# training phase
# Train Loss: 0.7271 Acc: 0.7138
# eval phase
# Validation Loss: 0.7752 Acc: 0.7054
#
# Epoch 56/79
# ----------
# training phase
# Train Loss: 0.7236 Acc: 0.7148
# eval phase
# Validation Loss: 0.7816 Acc: 0.7040
#
# Epoch 57/79
# ----------
# training phase
# Train Loss: 0.7234 Acc: 0.7173
# eval phase
# Validation Loss: 0.7750 Acc: 0.7033
#
# Epoch 58/79
# ----------
# training phase
# Train Loss: 0.7214 Acc: 0.7194
# eval phase
# Validation Loss: 0.7776 Acc: 0.7033
#
# Epoch 59/79
# ----------
# training phase
# Train Loss: 0.7323 Acc: 0.7128
# eval phase
# Validation Loss: 0.7775 Acc: 0.7088
#
# Epoch 60/79
# ----------
# training phase
# Train Loss: 0.7312 Acc: 0.7135
# eval phase
# Validation Loss: 0.7775 Acc: 0.7054
#
# Epoch 61/79
# ----------
# training phase
# Train Loss: 0.7307 Acc: 0.7164
# eval phase
# Validation Loss: 0.7786 Acc: 0.7020
#
# Epoch 62/79
# ----------
# training phase
# Train Loss: 0.7276 Acc: 0.7189
# eval phase
# Validation Loss: 0.7748 Acc: 0.7027
#
# Epoch 63/79
# ----------
# training phase
# Train Loss: 0.7269 Acc: 0.7141
# eval phase
# Validation Loss: 0.7790 Acc: 0.7023
#
# Epoch 64/79
# ----------
# training phase
# Train Loss: 0.7275 Acc: 0.7150
# eval phase
# Validation Loss: 0.7794 Acc: 0.7010
#
# Epoch 65/79
# ----------
# training phase
# Train Loss: 0.7284 Acc: 0.7160
# eval phase
# Validation Loss: 0.7828 Acc: 0.7068
#
# Epoch 66/79
# ----------
# training phase
# Train Loss: 0.7265 Acc: 0.7164
# eval phase
# Validation Loss: 0.7799 Acc: 0.7016
#
# Epoch 67/79
# ----------
# training phase
# Train Loss: 0.7237 Acc: 0.7158
# eval phase
# Validation Loss: 0.7801 Acc: 0.7051
#
# Epoch 68/79
# ----------
# training phase
# Train Loss: 0.7262 Acc: 0.7148
# eval phase
# Validation Loss: 0.7770 Acc: 0.7054
#
# Epoch 69/79
# ----------
# training phase
# Train Loss: 0.7235 Acc: 0.7169
# eval phase
# Validation Loss: 0.7761 Acc: 0.7061
#
# Epoch 70/79
# ----------
# training phase
# Train Loss: 0.7300 Acc: 0.7134
# eval phase
# Validation Loss: 0.7784 Acc: 0.7044
#
# Epoch 71/79
# ----------
# training phase
# Train Loss: 0.7251 Acc: 0.7157
# eval phase
# Validation Loss: 0.7791 Acc: 0.7068
#
# Epoch 72/79
# ----------
# training phase
# Train Loss: 0.7298 Acc: 0.7122
# eval phase
# Validation Loss: 0.7767 Acc: 0.7027
#
# Epoch 73/79
# ----------
# training phase
# Train Loss: 0.7217 Acc: 0.7167
# eval phase
# Validation Loss: 0.7776 Acc: 0.7051
#
# Epoch 74/79
# ----------
# training phase
# Train Loss: 0.7280 Acc: 0.7148
# eval phase
# Validation Loss: 0.7813 Acc: 0.7040
#
# Epoch 75/79
# ----------
# training phase
# Train Loss: 0.7252 Acc: 0.7142
# eval phase
# Validation Loss: 0.7785 Acc: 0.7037
#
# Epoch 76/79
# ----------
# training phase
# Train Loss: 0.7269 Acc: 0.7128
# eval phase
# Validation Loss: 0.7822 Acc: 0.7030
#
# Epoch 77/79
# ----------
# training phase
# Train Loss: 0.7293 Acc: 0.7157
# eval phase
# Validation Loss: 0.7772 Acc: 0.7013
#
# Epoch 78/79
# ----------
# training phase
# Train Loss: 0.7239 Acc: 0.7164
# eval phase
# Validation Loss: 0.7801 Acc: 0.7023
#
# Epoch 79/79
# ----------
# training phase
# Train Loss: 0.7278 Acc: 0.7161
# eval phase
# Validation Loss: 0.7788 Acc: 0.6975
#
# Training complete in 38m 25s
# Best val Acc: 0.708817

# %% [markdown]
# ### Plot the loss and accuracy values during training for the train and validation sets

# %%
# Plot the history
plot_history(history)

# %% [markdown]
# ### Plot performance metrics such as accuracy, precision, recall and f1-score as well as the **Confusion Matrix**

# %%
# Get predictions for the test set
y_true = []
y_pred = []
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

# %%
# Calculate metrics
calculate_metrics(y_true, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.65      0.63       491
#            1       0.59      0.32      0.42       528
#            2       0.86      0.90      0.88       879
#            3       0.55      0.72      0.62       594
#            4       0.76      0.76      0.76       416
#
#     accuracy                           0.69      2908
#    macro avg       0.68      0.67      0.66      2908
# weighted avg       0.69      0.69      0.68      2908

# %%
# Plot confusion matrix
plot_confusion_matrix(y_true, y_pred)
