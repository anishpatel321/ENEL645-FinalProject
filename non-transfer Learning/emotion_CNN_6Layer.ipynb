# %% [markdown]
# ### Import libraries as needed

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchsummary import summary
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset, SubsetRandomSampler, Dataset
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import time
import copy
from torchvision.datasets import ImageFolder
from torchvision import transforms

# %% [markdown]
# ### Define helper functions

# %%
###########################################################################################

# Function to plot the training and validation accuracy and loss --------------------------
def plot_history(history):
    fig, axs = plt.subplots(2)

    # Create accuracy subplot
    axs[0].plot([acc.cpu().numpy() for acc in history['train_acc']], label="train accuracy")
    axs[0].plot([acc.cpu().numpy() for acc in history['val_acc']], label="validation accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy Evaluation")

    # Create error subplot
    axs[1].plot(history['train_loss'], label="train error")
    axs[1].plot(history['val_loss'], label="validation error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error Evaluation")

    plt.show()

###########################################################################################

# Function to visualize some images before you train --------------------------------------
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    plt.imshow(inp, cmap='gray')
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

############################################################################################

# Function to visualize sample count before split ------------------------------------------
def plot_class_distribution(counts, title):
    labels = [f"{idx}: {idx_to_class[idx]}" for idx in counts.keys()]
    values = list(counts.values())

    plt.figure(figsize=(10,5))
    plt.bar(labels, values)
    plt.xlabel('Class')
    plt.ylabel('Count')
    plt.title(title)
    plt.xticks(rotation=90)
    plt.show()

############################################################################################

# Function to plot the confusion matrix
def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 10))
    sns.heatmap(cm, annot=True, fmt=".0f", linewidths=.5, square=True, cmap='Blues');
    plt.ylabel('Actual Label');
    plt.xlabel('Predicted Label');
    plt.title('Confusion Matrix', size=15);
    plt.show()

############################################################################################

# Function for classification report for perfomance metrics
from sklearn import preprocessing
def calculate_metrics(y_true, y_pred):
    le = preprocessing.LabelEncoder()
    le.fit(y_true)
    class_names = [str(cls) for cls in le.classes_]
    print(classification_report(y_true, y_pred, target_names=class_names))

############################################################################################

# %% [markdown]
# ### Define function to **train** the model

# %%
def train_model(model, criterion, optimizer, scheduler, dataloaders, num_epochs=80):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model.to(device)

    # Initialize the history
    history = {'train_loss': [], 'val_loss': [], 'train_acc': [], 'val_acc': []}

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['Train', 'Validation']:
            if phase == 'Train':
                model.train()  # Set model to training mode
                print("training phase")
            else:
                model.eval()   # Set model to evaluate mode
                print("eval phase")

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:

                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'Train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'Train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                #print("end inner loop")

            if phase == 'Train':
                scheduler.step()

            # epoch_loss = running_loss / dataset_sizes[phase]
            # epoch_acc = running_corrects.double() / dataset_sizes[phase]
            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'Validation' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
                torch.save(model.state_dict(), f'bestmodel_6layer.pth')

            # Save the loss and accuracy in history
            if phase == 'Train':
                history['train_loss'].append(epoch_loss)
                history['train_acc'].append(epoch_acc)
            else:
                history['val_loss'].append(epoch_loss)
                history['val_acc'].append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, history

# %% [markdown]
# # find stdev and mean of full dataset

# %%
# Load your train and test datasets
train_dir = 'C:/Users/Anish Patel/Desktop/ENSF645 Final Project/Dataset/train'
test_dir = 'C:/Users/Anish Patel/Desktop/ENSF645 Final Project/Dataset/test'

train_data = ImageFolder(root=train_dir, transform=transforms.ToTensor())
test_data = ImageFolder(root=test_dir, transform=transforms.ToTensor())

# Calculate the mean and standard deviation for the train dataset
mean_train = torch.stack([torch.mean(image.float(), dim=[1,2]) for image, _ in train_data]).mean(dim=0)
std_train = torch.stack([torch.std(image.float(), dim=[1,2]) for image, _ in train_data]).std(dim=0)

# Calculate the mean and standard deviation for the test dataset
mean_test = torch.stack([torch.mean(image.float(), dim=[1,2]) for image, _ in test_data]).mean(dim=0)
std_test = torch.stack([torch.std(image.float(), dim=[1,2]) for image, _ in test_data]).std(dim=0)

print('Train Dataset: Mean: ', mean_train, ', Standard Deviation: ', std_train)
print('Test Dataset: Mean: ', mean_test, ', Standard Deviation: ', std_test)
# Out:
# Train Dataset: Mean:  tensor([0.5120, 0.5120, 0.5120]) , Standard Deviation:  tensor([0.0526, 0.0526, 0.0526])
# Test Dataset: Mean:  tensor([0.5099, 0.5099, 0.5099]) , Standard Deviation:  tensor([0.0528, 0.0528, 0.0528])

# %% [markdown]
# ### Load data, setup dataloaders, and visualize sample counts

# %%
# Define your transformations
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),  # Horizontal mirroring
    transforms.RandomRotation(10),  # ±10 degree rotations
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),  # Convert the PIL Image to a tensor
    transforms.Normalize(mean=[0.5120], std=[0.0526])  # Normalize the images
])

# Define your transformations for the validation and test sets
val_test_transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),  # Convert the PIL Image to a tensor
    transforms.Normalize(mean=[0.5099], std=[0.0528])  # Normalize the images
])

train_dir = 'C:/Users/Anish Patel/Desktop/ENSF645 Final Project/Dataset/train'
test_dir = 'C:/Users/Anish Patel/Desktop/ENSF645 Final Project/Dataset/test'

# Load the datasets
train_data = datasets.ImageFolder(train_dir, transform=train_transform)
test_data = datasets.ImageFolder(test_dir, transform=val_test_transform)

# %%
print(train_data.classes)
# Out:
# ['angry', 'fear', 'happy', 'sad', 'surprise']

# %%
# Get the class names
class_names_train = test_data.classes
class_names_test = test_data.classes

# Create a dictionary mapping indices to class names
idx_to_class_train = {i: class_name for i, class_name in enumerate(class_names_train)}
idx_to_class_test = {i: class_name for i, class_name in enumerate(class_names_test)}

# Count labels in the original dataset for train and test
train_counts = Counter(train_data.targets)
test_counts = Counter(test_data.targets)

# Adjust the counts to exclude 'happy_2'
train_counts = {i: count for i, count in train_counts.items() if i in idx_to_class_train.keys()}

# Print the counts
print("Train Counts:", {idx_to_class_train[i]: count for i, count in train_counts.items()})
print("Test Counts:", {idx_to_class_test[i]: count for i, count in test_counts.items()})
# Out:
# Train Counts: {'angry': 3995, 'fear': 4097, 'happy': 7215, 'sad': 4830, 'surprise': 3171}
# Test Counts: {'angry': 958, 'fear': 1024, 'happy': 1774, 'sad': 1247, 'surprise': 831}

# %%
# Get the indices of the samples in the validation and test sets
test_indices = [i for i, (img_path, _) in enumerate(test_data.imgs) if 'Private' in img_path]
valid_indices = [i for i, (img_path, _) in enumerate(test_data.imgs) if 'Private' not in img_path]

# Create subset datasets
validation_data = torch.utils.data.Subset(test_data, valid_indices)
test_data = torch.utils.data.Subset(test_data, test_indices)

# Create data loaders
batch_size = 32
num_workers = 2
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=num_workers)
validation_loader = DataLoader(validation_data, batch_size=batch_size, shuffle=True, num_workers=num_workers)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=True, num_workers=num_workers)

dataloaders = {
    'Train': train_loader,
    'Validation': validation_loader,
    'Test': test_loader
}

# %%
print("Length of Train Loader: ", len(dataloaders['Train']))
print("Length of Validation Loader: ", len(dataloaders['Validation']))
print("Total count of samples in train set:", len(train_data))
print("Total count of samples in validation set:", len(validation_data))
print("Total count of samples in test set:", len(test_data))
# Out:
# Length of Train Loader:  729
# Length of Validation Loader:  92
# Total count of samples in train set: 23308
# Total count of samples in validation set: 2926
# Total count of samples in test set: 2908

# %%
# Get the class names
class_names = train_data.classes

# Create a dictionary mapping indices to class names
idx_to_class = {i: class_name for i, class_name in enumerate(class_names)}

# Count labels in the original dataset for train
original_counts = Counter(train_data.targets)

# Count labels in the subsets
valid_counts = Counter(test_data.dataset.targets[i] for i in valid_indices)
test_counts = Counter(test_data.dataset.targets[i] for i in test_indices)

# Plot
plot_class_distribution(original_counts, 'Train Counts')
plot_class_distribution(valid_counts, 'Validation Counts')
plot_class_distribution(test_counts, 'Test Counts')

# %%
print("Train Counts:", {idx_to_class[i]: count for i, count in original_counts.items()})
print("Validation Counts:", {idx_to_class[i]: count for i, count in valid_counts.items()})
print("Test Counts:", {idx_to_class[i]: count for i, count in test_counts.items()})
# Out:
# Train Counts: {'angry': 3995, 'fear': 4097, 'happy': 7215, 'sad': 4830, 'surprise': 3171}
# Validation Counts: {'angry': 467, 'fear': 496, 'happy': 895, 'sad': 653, 'surprise': 415}
# Test Counts: {'angry': 491, 'fear': 528, 'happy': 879, 'sad': 594, 'surprise': 416}

# %% [markdown]
# ####Data seems to be imbalanced with happy class having a lot more data, remaining classes seem to be somewhat equal

# %% [markdown]
# ### Visualize some sample from the training set before training

# %%
# Get a batch of training data
inputs, classes = next(iter(train_loader))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)
imshow(out)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Define a baseline CNN model

# %%
import torch.nn.functional as F

class SixLayerCNN(nn.Module):
    def __init__(self):
        super(SixLayerCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 128, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(128)
        self.conv2 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(256)
        self.conv3 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(512)
        self.conv4 = nn.Conv2d(512, 1024, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(1024)
        self.conv5 = nn.Conv2d(1024, 1024, kernel_size=3, padding=1)
        self.bn5 = nn.BatchNorm2d(1024)
        self.conv6 = nn.Conv2d(1024, 2048, kernel_size=3, padding=1)
        self.bn6 = nn.BatchNorm2d(2048)
        self.pool = nn.MaxPool2d(2, 2)
        self.dropout = nn.Dropout(0.25)
        self.gap = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(2048, 5)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = self.pool(x)  # Apply pooling here
        x = self.dropout(x)
        
        x = F.relu(self.bn2(self.conv2(x)))
        # No pooling here to preserve feature map size
        
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.pool(x)  # Apply pooling here
        x = self.dropout(x)
        
        x = F.relu(self.bn4(self.conv4(x)))
        # No pooling here to preserve feature map size
        
        x = F.relu(self.bn5(self.conv5(x)))
        # No pooling here to preserve feature map size
        
        x = F.relu(self.bn6(self.conv6(x)))
        # No pooling here to preserve feature map size
        
        x = self.gap(x)  # Global Average Pooling to reduce to 1x1 per channel
        x = x.view(x.size(0), -1)  # Flatten
        x = self.fc(x)
        return x

# %%
# Assuming that your model is defined and moved to the correct device
model = SixLayerCNN()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
  print("using gpu")
else:
  print("using cpu")

model = model.to(device)

# Print the summary
summary(model, input_size=(1, 48, 48))
# Out:
# using gpu
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 128, 48, 48]           1,280
#        BatchNorm2d-2          [-1, 128, 48, 48]             256
#          MaxPool2d-3          [-1, 128, 24, 24]               0
#            Dropout-4          [-1, 128, 24, 24]               0
#             Conv2d-5          [-1, 256, 24, 24]         295,168
#        BatchNorm2d-6          [-1, 256, 24, 24]             512
#             Conv2d-7          [-1, 512, 24, 24]       1,180,160
#        BatchNorm2d-8          [-1, 512, 24, 24]           1,024
#          MaxPool2d-9          [-1, 512, 12, 12]               0
#           Dropout-10          [-1, 512, 12, 12]               0
#            Conv2d-11         [-1, 1024, 12, 12]       4,719,616
#       BatchNorm2d-12         [-1, 1024, 12, 12]           2,048
#            Conv2d-13         [-1, 1024, 12, 12]       9,438,208
#       BatchNorm2d-14         [-1, 1024, 12, 12]           2,048
#            Conv2d-15         [-1, 2048, 12, 12]      18,876,416
#       BatchNorm2d-16         [-1, 2048, 12, 12]           4,096
# AdaptiveAvgPool2d-17           [-1, 2048, 1, 1]               0
#            Linear-18                    [-1, 5]          10,245
# ================================================================
# Total params: 34,531,077
# Trainable params: 34,531,077
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 22.52
# Params size (MB): 131.73
# Estimated Total Size (MB): 154.25
# ----------------------------------------------------------------

# %% [markdown]
# ### Send model to gpu and define loss function, step optimizer, learning rate scheduler

# %%
# Define the criterion
criterion = nn.CrossEntropyLoss()

# Define the optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Define the learning rate scheduler
scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

# Calculate dataset sizes
dataset_sizes = {
    'Train': len(train_data),
    'Validation': len(validation_data),
    'Test': len(test_data)
}

# %% [markdown]
# ### Train the model

# %%
model, history = train_model(model, criterion, optimizer, scheduler, dataloaders, num_epochs=80)
# model = train_model(model, criterion, optimizer, dataloaders, num_epochs=80)
# Out:
# Epoch 0/79
# ----------
# training phase
# Train Loss: 1.5377 Acc: 0.3343
# eval phase
# Validation Loss: 1.5313 Acc: 0.3599
#
# Epoch 1/79
# ----------
# training phase
# Train Loss: 1.2365 Acc: 0.4845
# eval phase
# Validation Loss: 1.1411 Acc: 0.5376
#
# Epoch 2/79
# ----------
# training phase
# Train Loss: 1.0967 Acc: 0.5529
# eval phase
# Validation Loss: 1.0873 Acc: 0.5608
#
# Epoch 3/79
# ----------
# training phase
# Train Loss: 1.0160 Acc: 0.5912
# eval phase
# Validation Loss: 1.1291 Acc: 0.5725
#
# Epoch 4/79
# ----------
# training phase
# Train Loss: 0.9528 Acc: 0.6140
# eval phase
# Validation Loss: 0.9565 Acc: 0.6193
#
# Epoch 5/79
# ----------
# training phase
# Train Loss: 0.9154 Acc: 0.6330
# eval phase
# Validation Loss: 0.8885 Acc: 0.6470
#
# Epoch 6/79
# ----------
# training phase
# Train Loss: 0.8841 Acc: 0.6438
# eval phase
# Validation Loss: 0.9038 Acc: 0.6422
#
# Epoch 7/79
# ----------
# training phase
# Train Loss: 0.7938 Acc: 0.6847
# eval phase
# Validation Loss: 0.8125 Acc: 0.6805
#
# Epoch 8/79
# ----------
# training phase
# Train Loss: 0.7710 Acc: 0.6934
# eval phase
# Validation Loss: 0.8124 Acc: 0.6835
#
# Epoch 9/79
# ----------
# training phase
# Train Loss: 0.7583 Acc: 0.6989
# eval phase
# Validation Loss: 0.8036 Acc: 0.6869
#
# Epoch 10/79
# ----------
# training phase
# Train Loss: 0.7474 Acc: 0.7043
# eval phase
# Validation Loss: 0.8042 Acc: 0.6928
#
# Epoch 11/79
# ----------
# training phase
# Train Loss: 0.7368 Acc: 0.7065
# eval phase
# Validation Loss: 0.7930 Acc: 0.6938
#
# Epoch 12/79
# ----------
# training phase
# Train Loss: 0.7253 Acc: 0.7138
# eval phase
# Validation Loss: 0.7943 Acc: 0.6934
#
# Epoch 13/79
# ----------
# training phase
# Train Loss: 0.7220 Acc: 0.7136
# eval phase
# Validation Loss: 0.8075 Acc: 0.6873
#
# Epoch 14/79
# ----------
# training phase
# Train Loss: 0.7053 Acc: 0.7228
# eval phase
# Validation Loss: 0.7872 Acc: 0.6965
#
# Epoch 15/79
# ----------
# training phase
# Train Loss: 0.6993 Acc: 0.7244
# eval phase
# Validation Loss: 0.7867 Acc: 0.6972
#
# Epoch 16/79
# ----------
# training phase
# Train Loss: 0.6933 Acc: 0.7276
# eval phase
# Validation Loss: 0.7848 Acc: 0.6989
#
# Epoch 17/79
# ----------
# training phase
# Train Loss: 0.6953 Acc: 0.7264
# eval phase
# Validation Loss: 0.7822 Acc: 0.6999
#
# Epoch 18/79
# ----------
# training phase
# Train Loss: 0.6917 Acc: 0.7263
# eval phase
# Validation Loss: 0.7784 Acc: 0.6962
#
# Epoch 19/79
# ----------
# training phase
# Train Loss: 0.6917 Acc: 0.7283
# eval phase
# Validation Loss: 0.7787 Acc: 0.7003
#
# Epoch 20/79
# ----------
# training phase
# Train Loss: 0.6920 Acc: 0.7259
# eval phase
# Validation Loss: 0.7843 Acc: 0.6996
#
# Epoch 21/79
# ----------
# training phase
# Train Loss: 0.6907 Acc: 0.7268
# eval phase
# Validation Loss: 0.7819 Acc: 0.7016
#
# Epoch 22/79
# ----------
# training phase
# Train Loss: 0.6874 Acc: 0.7299
# eval phase
# Validation Loss: 0.7841 Acc: 0.7027
#
# Epoch 23/79
# ----------
# training phase
# Train Loss: 0.6881 Acc: 0.7288
# eval phase
# Validation Loss: 0.7836 Acc: 0.7003
#
# Epoch 24/79
# ----------
# training phase
# Train Loss: 0.6846 Acc: 0.7317
# eval phase
# Validation Loss: 0.7840 Acc: 0.7006
#
# Epoch 25/79
# ----------
# training phase
# Train Loss: 0.6825 Acc: 0.7310
# eval phase
# Validation Loss: 0.7822 Acc: 0.7010
#
# Epoch 26/79
# ----------
# training phase
# Train Loss: 0.6870 Acc: 0.7311
# eval phase
# Validation Loss: 0.7812 Acc: 0.7016
#
# Epoch 27/79
# ----------
# training phase
# Train Loss: 0.6862 Acc: 0.7285
# eval phase
# Validation Loss: 0.7815 Acc: 0.6999
#
# Epoch 28/79
# ----------
# training phase
# Train Loss: 0.6866 Acc: 0.7263
# eval phase
# Validation Loss: 0.7793 Acc: 0.6999
#
# Epoch 29/79
# ----------
# training phase
# Train Loss: 0.6884 Acc: 0.7313
# eval phase
# Validation Loss: 0.7861 Acc: 0.7023
#
# Epoch 30/79
# ----------
# training phase
# Train Loss: 0.6865 Acc: 0.7283
# eval phase
# Validation Loss: 0.7839 Acc: 0.6999
#
# Epoch 31/79
# ----------
# training phase
# Train Loss: 0.6845 Acc: 0.7282
# eval phase
# Validation Loss: 0.7781 Acc: 0.7013
#
# Epoch 32/79
# ----------
# training phase
# Train Loss: 0.6863 Acc: 0.7304
# eval phase
# Validation Loss: 0.7849 Acc: 0.7006
#
# Epoch 33/79
# ----------
# training phase
# Train Loss: 0.6875 Acc: 0.7293
# eval phase
# Validation Loss: 0.7795 Acc: 0.7010
#
# Epoch 34/79
# ----------
# training phase
# Train Loss: 0.6840 Acc: 0.7305
# eval phase
# Validation Loss: 0.7797 Acc: 0.6999
#
# Epoch 35/79
# ----------
# training phase
# Train Loss: 0.6852 Acc: 0.7294
# eval phase
# Validation Loss: 0.7826 Acc: 0.7023
#
# Epoch 36/79
# ----------
# training phase
# Train Loss: 0.6852 Acc: 0.7303
# eval phase
# Validation Loss: 0.7810 Acc: 0.7003
#
# Epoch 37/79
# ----------
# training phase
# Train Loss: 0.6851 Acc: 0.7293
# eval phase
# Validation Loss: 0.7832 Acc: 0.7006
#
# Epoch 38/79
# ----------
# training phase
# Train Loss: 0.6860 Acc: 0.7306
# eval phase
# Validation Loss: 0.7812 Acc: 0.6996
#
# Epoch 39/79
# ----------
# training phase
# Train Loss: 0.6830 Acc: 0.7320
# eval phase
# Validation Loss: 0.7900 Acc: 0.6975
#
# Epoch 40/79
# ----------
# training phase
# Train Loss: 0.6880 Acc: 0.7286
# eval phase
# Validation Loss: 0.7817 Acc: 0.7013
#
# Epoch 41/79
# ----------
# training phase
# Train Loss: 0.6882 Acc: 0.7313
# eval phase
# Validation Loss: 0.7777 Acc: 0.7013
#
# Epoch 42/79
# ----------
# training phase
# Train Loss: 0.6896 Acc: 0.7307
# eval phase
# Validation Loss: 0.7848 Acc: 0.6996
#
# Epoch 43/79
# ----------
# training phase
# Train Loss: 0.6856 Acc: 0.7285
# eval phase
# Validation Loss: 0.7832 Acc: 0.7023
#
# Epoch 44/79
# ----------
# training phase
# Train Loss: 0.6858 Acc: 0.7288
# eval phase
# Validation Loss: 0.7839 Acc: 0.7010
#
# Epoch 45/79
# ----------
# training phase
# Train Loss: 0.6905 Acc: 0.7282
# eval phase
# Validation Loss: 0.7809 Acc: 0.6979
#
# Epoch 46/79
# ----------
# training phase
# Train Loss: 0.6888 Acc: 0.7308
# eval phase
# Validation Loss: 0.7820 Acc: 0.6986
#
# Epoch 47/79
# ----------
# training phase
# Train Loss: 0.6858 Acc: 0.7297
# eval phase
# Validation Loss: 0.7801 Acc: 0.6982
#
# Epoch 48/79
# ----------
# training phase
# Train Loss: 0.6854 Acc: 0.7324
# eval phase
# Validation Loss: 0.7871 Acc: 0.7010
#
# Epoch 49/79
# ----------
# training phase
# Train Loss: 0.6875 Acc: 0.7281
# eval phase
# Validation Loss: 0.7823 Acc: 0.7003
#
# Epoch 50/79
# ----------
# training phase
# Train Loss: 0.6880 Acc: 0.7290
# eval phase
# Validation Loss: 0.7879 Acc: 0.7010
#
# Epoch 51/79
# ----------
# training phase
# Train Loss: 0.6858 Acc: 0.7306
# eval phase
# Validation Loss: 0.7838 Acc: 0.7006
#
# Epoch 52/79
# ----------
# training phase
# Train Loss: 0.6911 Acc: 0.7285
# eval phase
# Validation Loss: 0.7828 Acc: 0.7006
#
# Epoch 53/79
# ----------
# training phase
# Train Loss: 0.6884 Acc: 0.7280
# eval phase
# Validation Loss: 0.7825 Acc: 0.7020
#
# Epoch 54/79
# ----------
# training phase
# Train Loss: 0.6847 Acc: 0.7315
# eval phase
# Validation Loss: 0.7853 Acc: 0.6989
#
# Epoch 55/79
# ----------
# training phase
# Train Loss: 0.6836 Acc: 0.7317
# eval phase
# Validation Loss: 0.7848 Acc: 0.7040
#
# Epoch 56/79
# ----------
# training phase
# Train Loss: 0.6888 Acc: 0.7286
# eval phase
# Validation Loss: 0.7823 Acc: 0.7023
#
# Epoch 57/79
# ----------
# training phase
# Train Loss: 0.6896 Acc: 0.7294
# eval phase
# Validation Loss: 0.7795 Acc: 0.7006
#
# Epoch 58/79
# ----------
# training phase
# Train Loss: 0.6848 Acc: 0.7307
# eval phase
# Validation Loss: 0.7830 Acc: 0.7006
#
# Epoch 59/79
# ----------
# training phase
# Train Loss: 0.6837 Acc: 0.7311
# eval phase
# Validation Loss: 0.7833 Acc: 0.7023
#
# Epoch 60/79
# ----------
# training phase
# Train Loss: 0.6881 Acc: 0.7290
# eval phase
# Validation Loss: 0.7861 Acc: 0.7033
#
# Epoch 61/79
# ----------
# training phase
# Train Loss: 0.6888 Acc: 0.7282
# eval phase
# Validation Loss: 0.7834 Acc: 0.6999
#
# Epoch 62/79
# ----------
# training phase
# Train Loss: 0.6916 Acc: 0.7305
# eval phase
# Validation Loss: 0.7833 Acc: 0.7006
#
# Epoch 63/79
# ----------
# training phase
# Train Loss: 0.6931 Acc: 0.7274
# eval phase
# Validation Loss: 0.7802 Acc: 0.7003
#
# Epoch 64/79
# ----------
# training phase
# Train Loss: 0.6840 Acc: 0.7311
# eval phase
# Validation Loss: 0.7864 Acc: 0.6992
#
# Epoch 65/79
# ----------
# training phase
# Train Loss: 0.6841 Acc: 0.7322
# eval phase
# Validation Loss: 0.7793 Acc: 0.7006
#
# Epoch 66/79
# ----------
# training phase
# Train Loss: 0.6878 Acc: 0.7270
# eval phase
# Validation Loss: 0.7800 Acc: 0.7006
#
# Epoch 67/79
# ----------
# training phase
# Train Loss: 0.6883 Acc: 0.7278
# eval phase
# Validation Loss: 0.7838 Acc: 0.7006
#
# Epoch 68/79
# ----------
# training phase
# Train Loss: 0.6881 Acc: 0.7263
# eval phase
# Validation Loss: 0.7824 Acc: 0.7040
#
# Epoch 69/79
# ----------
# training phase
# Train Loss: 0.6864 Acc: 0.7283
# eval phase
# Validation Loss: 0.7870 Acc: 0.7020
#
# Epoch 70/79
# ----------
# training phase
# Train Loss: 0.6870 Acc: 0.7304
# eval phase
# Validation Loss: 0.7907 Acc: 0.6982
#
# Epoch 71/79
# ----------
# training phase
# Train Loss: 0.6860 Acc: 0.7291
# eval phase
# Validation Loss: 0.7828 Acc: 0.7006
#
# Epoch 72/79
# ----------
# training phase
# Train Loss: 0.6876 Acc: 0.7277
# eval phase
# Validation Loss: 0.7807 Acc: 0.7003
#
# Epoch 73/79
# ----------
# training phase
# Train Loss: 0.6885 Acc: 0.7285
# eval phase
# Validation Loss: 0.7788 Acc: 0.7003
#
# Epoch 74/79
# ----------
# training phase
# Train Loss: 0.6867 Acc: 0.7284
# eval phase
# Validation Loss: 0.7825 Acc: 0.7003
#
# Epoch 75/79
# ----------
# training phase
# Train Loss: 0.6893 Acc: 0.7271
# eval phase
# Validation Loss: 0.7815 Acc: 0.6999
#
# Epoch 76/79
# ----------
# training phase
# Train Loss: 0.6837 Acc: 0.7292
# eval phase
# Validation Loss: 0.7825 Acc: 0.7013
#
# Epoch 77/79
# ----------
# training phase
# Train Loss: 0.6862 Acc: 0.7300
# eval phase
# Validation Loss: 0.7785 Acc: 0.6986
#
# Epoch 78/79
# ----------
# training phase
# Train Loss: 0.6868 Acc: 0.7308
# eval phase
# Validation Loss: 0.7817 Acc: 0.7016
#
# Epoch 79/79
# ----------
# training phase
# Train Loss: 0.6876 Acc: 0.7308
# eval phase
# Validation Loss: 0.7808 Acc: 0.7010
#
# Training complete in 114m 23s
# Best val Acc: 0.704033

# %% [markdown]
# ### Plot the loss and accuracy values during training for the train and validation sets

# %%
# Plot the history
plot_history(history)

# %% [markdown]
# ### Plot performance metrics such as accuracy, precision, recall and f1-score as well as the **Confusion Matrix**

# %%
# Get predictions for the test set
y_true = []
y_pred = []
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

# %%
# Calculate metrics
calculate_metrics(y_true, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60       491
#            1       0.57      0.42      0.48       528
#            2       0.86      0.92      0.89       879
#            3       0.60      0.67      0.64       594
#            4       0.78      0.78      0.78       416
#
#     accuracy                           0.71      2908
#    macro avg       0.68      0.68      0.68      2908
# weighted avg       0.70      0.71      0.70      2908

# %%
# Plot confusion matrix
plot_confusion_matrix(y_true, y_pred)
